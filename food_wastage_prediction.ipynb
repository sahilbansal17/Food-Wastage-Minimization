# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[310, 6], [300,8], [260, 7], [250, 6]])
# [no of students, raw_dal_qty_used in kgs]
print(X)
# Out:
# [[310   6]
#  [300   8]
#  [260   7]
#  [250   6]]

# %%
y = [0.0, 2.0,2.0, 1.0]
# qty of raw_dal wasted in kgs

# %%
reg = LinearRegression().fit(X, y)
# reg.score(X, y)

# %%
threshold = 0.05 # min dal_raw assumed to be wasted

# %%
reg.predict(np.array([[299, 5.3]])) + threshold
reg.predict(np.array([[299, 5]])) + threshold
reg.predict(np.array([[299, 3]])) + threshold
# Out:
# array([-2.64222222])

# %%
x = 0.0
wastageitr = 10.0
tmp = 0
prod = 2.0
while(x < 10.0):
    tmp = reg.predict(np.array([[299, x]]))
    
    if(tmp > 0 and tmp < wastageitr):
        wastageitr = tmp
        prod = x
    x += 0.1

print(wastageitr)
print(prod)
# Out:
# [0.07888889]
# 5.899999999999995

# %%
Number = []
Prod = []
Wastage = []
Percentage_Save = []

# %%
for i in range(300,500):
    x = 0.0
    wastageitr = 20.0
    tmp = 0
    prod = 2.0
    
    while(x < 20.0):
        tmp = reg.predict(np.array([[i, x]]))
    
        if(tmp > 0 and tmp < wastageitr):
            wastageitr = tmp
            prod = x
        x += 0.1
        
    Number.append(i)
    Prod.append(prod)
    Percentage_Save.append( (100-abs(wastageitr))*(100)/(2) )
    Wastage.append(wastageitr)

# %%
Number
# Out:
# [300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384,
#  385,
#  386,
#  387,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  396,
#  397,
#  398,
#  399,
#  400,
#  401,
#  402,
#  403,
#  404,
#  405,
#  406,
#  407,
#  408,
#  409,
#  410,
#  411,
#  412,
#  413,
#  414,
#  415,
#  416,
#  417,
#  418,
#  419,
#  420,
#  421,
#  422,
#  423,
#  424,
# ...

# %%
Prod
# Out:
# [5.899999999999995,
#  5.899999999999995,
#  5.899999999999995,
#  5.899999999999995,
#  5.999999999999995,
#  5.999999999999995,
#  5.999999999999995,
#  5.999999999999995,
#  5.999999999999995,
#  6.099999999999994,
#  6.099999999999994,
#  6.099999999999994,
#  6.099999999999994,
#  6.099999999999994,
#  6.199999999999994,
#  6.199999999999994,
#  6.199999999999994,
#  6.199999999999994,
#  6.199999999999994,
#  6.299999999999994,
#  6.299999999999994,
#  6.299999999999994,
#  6.299999999999994,
#  6.299999999999994,
#  6.399999999999993,
#  6.399999999999993,
#  6.399999999999993,
#  6.399999999999993,
#  6.399999999999993,
#  6.499999999999993,
#  6.499999999999993,
#  6.499999999999993,
#  6.499999999999993,
#  6.499999999999993,
#  6.5999999999999925,
#  6.5999999999999925,
#  6.5999999999999925,
#  6.5999999999999925,
#  6.5999999999999925,
#  6.699999999999992,
#  6.699999999999992,
#  6.699999999999992,
#  6.699999999999992,
#  6.699999999999992,
#  6.799999999999992,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Number,Prod)
plt.axis([300,499, 5.88, 15])
plt.show()

# %%
plt.plot(Number[::2],Wastage[::2])
plt.axis([300,500, 0, 1])
plt.show()

# %%
print(Percentage_Save[0])
# Out:
# [4997.]
